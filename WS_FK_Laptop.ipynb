# %%
from selenium import webdriver

# %%
from bs4 import BeautifulSoup as bs

# %%
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path='D:\\Python\\chromedriver.exe')

# %%
products=[]
prices=[]
ratings=[]

# %%
driver.get(<a href="https://www.flipkart.com/laptops/">)
# Out:
#   File "<ipython-input-25-1ee77e55050a>", line 1
#     driver.get(<a href="https://www.flipkart.com/laptops/">)
#                ^
# SyntaxError: invalid syntax

# %%
driver.get("<a href="https://img1a.flixcart.com" rel="dns-prefetch">")
# Out:
#   File "<ipython-input-28-861f433d7f20>", line 1
#     driver.get("<a href="https://img1a.flixcart.com" rel="dns-prefetch">")
#                              ^
# SyntaxError: invalid syntax

# %%
driver.get("https://www.flipkart.com");

# %%
driver.get("<a href="https://www.flipkart.com/laptops/">https://www.flipkart.com/laptops/</a>~buyback-guarantee-on-laptops-/pr?sid=6bo%2Cb5g&uniq");
# Out:
#   File "<ipython-input-30-065029b630e9>", line 1
#     driver.get("<a href="https://www.flipkart.com/laptops/">https://www.flipkart.com/laptops/</a>~buyback-guarantee-on-laptops-/pr?sid=6bo%2Cb5g&uniq");
#                              ^
# SyntaxError: invalid syntax

# %%
content = driver.page_source

# %%
content
# Out:
# '<html lang="en" class=" fonts-loaded"><head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch">\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch">\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.247a55.css">\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge">\n\t<meta property="fb:page_id" content="102988293558">\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389">\n\t<meta name="robots" content="noodp">\n\n\t<link rel="shortcut icon" href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico">\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2">\n\n\t<meta property="og:type" content="website">\n\t<meta name="og_site_name" property="og:site_n
# ...

# %%
soup
# Out:
# <html class="fonts-loaded" lang="en"><head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.247a55.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
soup = bs(content)

# %%
for a in soup.findAll('a',href=True, attrs={'class':'_33x-Wq'}):
name=a.find('div', attrs={'class':'col-12-12 _1PBbw8'})
price=a.find('div', attrs={'class':'_1vC4OE _2rQ-NK'})
rating=a.find('div', attrs={'class':'hGSR34 _2beYZw'})
# Out:
#   File "<ipython-input-42-a2dceef2bb1d>", line 2
#     name=a.find('div', attrs={'class':'col-12-12 _1PBbw8'})
#        ^
# IndentationError: expected an indented block

# %%
for a in soup.findAll('a',href=True, attrs={'class':'_1EgM1b'}):
name=a.find('div', attrs={'class':'_2tnqd0'})
# Out:
#   File "<ipython-input-43-386b1dc43806>", line 2
#     name=a.find('div', attrs={'class':'_2tnqd0'})
#        ^
# IndentationError: expected an indented block

# %%
for a in soup.findAll('a',href=True, attrs={'class':'_33x-Wq'}):
name=a.find('div', attrs={'class':'col-12-12 _1PBbw8'})
products.append(name.text)
# Out:
#   File "<ipython-input-45-0d21626bd7b2>", line 2
#     name=a.find('div', attrs={'class':'col-12-12 _1PBbw8'})
#        ^
# IndentationError: expected an indented block

# %%
for a in soup.findAll('a',href=True, attrs={'class':'_33x-Wq'}):
name=a.find('div', attrs={'class':'col-12-12 _1PBbw8'})
# Out:
#   File "<ipython-input-47-2352aff153ca>", line 2
#     name=a.find('div', attrs={'class':'col-12-12 _1PBbw8'})
#        ^
# IndentationError: expected an indented block
